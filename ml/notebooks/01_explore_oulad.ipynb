# %% [markdown]
# # 01 — Explore OULAD
#
# Run `python src/preprocess_oulad.py` after `extract_datasets.py`, then open `../data/processed/oulad_features.csv`.
# Labels `final_result` and `at_risk` are for training only — never use as input features in `train_oulad_models.py`.

# %%
import pandas as pd
from pathlib import Path
p = Path('../data/processed/oulad_features.csv')
df = pd.read_csv(p, nrows=5000)
df.head()
