# %% [markdown]
# # 02 — Explore Education Dialogue
#
# Heuristic labels in `dialogue_features.csv` are **proof-of-concept** only — not validated ground truth.
# See `../src/preprocess_dialogue.py` for parsing rules.

# %%
import pandas as pd
from pathlib import Path
p = Path('../data/processed/dialogue_features.csv')
df = pd.read_csv(p, nrows=2000)
df[['conversation_id','reflection_quality','confusion_detected','reasoning_depth']].head(10)
